# %% [markdown]
# Do it Pyhton! 03장

# %% [markdown]
# 2-2 문자형 자료형

# %%
multiline = ''' Life is short 
you need python
'''
print(multiline)
# Out:
#  Life is short
# you need python

# %%
a= "Life is short you need python"
print(a[0:4])
print(a[:9])
# Out:
# Life
# Life is s

# %%
"I eat %s apples" %"five"
"I eat %s apples" %"3%"
# Out:
# 'I eat 3% apples'

# %%
"I eat {0} apples".format("three")

"I eat {t} apples and sick for {g} days".format(t="three",g="two")
# Out:
# 'I eat three apples and sick for two days'

# %%
"I eat {0:>10} apples".format("three")
"I eat {0:=^11} apples".format("three")
# Out:
# 'I eat ===three=== apples'

# %%
name = "나"
age = 10
f'나의 이름은 {name} 나이는 {age}'
# Out:
# '나의 이름은 나 나이는 10'

# %%
f'{"hi":>10}'
f'{"python":!^12}'
# Out:
# '!!!python!!!'

# %%
a="robin"
a.count('o')
# Out:
# 1

# %%
a="fsdjfksdjfksdjfkjeawkbvanslkfjergtuf"
a.find('z')
# Out:
# -1

# %%
"!".join(["11234","456"])
# Out:
# '11234!456'

# %%
a="   f"
a.lstrip()
# Out:
# 'f'

# %%
a="life is too short"
a.replace("life","jj")
# Out:
# 'jj is too short'

# %%
a="life is too short"
a.split()
# Out:
# ['life', 'is', 'too', 'short']

# %% [markdown]
# 2-3 리스트 자료형

# %%
i = [0,1,2,3,4,5]
for i<10:
print(i)
# Out:
#   File "<ipython-input-4-a52e6a62805b>", line 2
#     for i, i<10:
#             ^
# SyntaxError: invalid syntax

# %%
print("'Hello'")
# Out:
# 'Hello'
